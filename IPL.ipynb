# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
dt=pd.read_csv('/content/drive/MyDrive/IPL.csv')
print(dt)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#       id  season        city        date                  team1  \
# 0      1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1      2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2      3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3      4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4      5    2008     Kolkata  2008-04-20        Deccan Chargers
# ..   ...     ...         ...         ...                    ...
# 572  573    2016      Raipur  2016-05-22       Delhi Daredevils
# 573  574    2016   Bangalore  2016-05-24          Gujarat Lions
# 574  575    2016       Delhi  2016-05-25    Sunrisers Hyderabad
# 575  576    2016       Delhi  2016-05-27          Gujarat Lions
# 576  577    2016   Bangalore  2016-05-29    Sunrisers Hyderabad
#
# ...

# %%
dt.head()
# Out:
#    id  season        city        date                  team1  \
# 0   1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1   2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2   3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3   4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4   5    2008     Kolkata  2008-04-20        Deccan Chargers
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# 2             Delhi Daredevils             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4        Kolkata Knight Riders              Deccan Chargers           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0        Kolkata Knight Riders          140
# ...

# %%
dt.tail()
# Out:
#       id  season       city        date                team1  \
# 572  573    2016     Raipur  2016-05-22     Delhi Daredevils
# 573  574    2016  Bangalore  2016-05-24        Gujarat Lions
# 574  575    2016      Delhi  2016-05-25  Sunrisers Hyderabad
# 575  576    2016      Delhi  2016-05-27        Gujarat Lions
# 576  577    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 572  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 573  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 574        Kolkata Knight Riders        Kolkata Knight Riders         field
# 575          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 576  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 572  normal           0  Royal Challengers Bangalore            0
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dt['city']
# Out:
# 0       Bangalore
# 1      Chandigarh
# 2           Delhi
# 3          Mumbai
# 4         Kolkata
#           ...
# 572        Raipur
# 573     Bangalore
# 574         Delhi
# 575         Delhi
# 576     Bangalore
# Name: city, Length: 577, dtype: object

# %%
dt.groupby('city').count()
# Out:
#                 id  season  date  team1  team2  toss_winner  toss_decision  \
# city
# Abu Dhabi        7       7     7      7      7            7              7
# Ahmedabad       12      12    12     12     12           12             12
# Bangalore       58      58    58     58     58           58             58
# Bloemfontein     2       2     2      2      2            2              2
# Cape Town        7       7     7      7      7            7              7
# Centurion       12      12    12     12     12           12             12
# Chandigarh      42      42    42     42     42           42             42
# Chennai         48      48    48     48     48           48             48
# Cuttack          7       7     7      7      7            7              7
# Delhi           53      53    53     53     53           53             53
# Dharamsala       9       9     9      9      9            9              9
# ...

# %%
print(dt.groupby('city').size())
# Out:
# city
# Abu Dhabi          7
# Ahmedabad         12
# Bangalore         58
# Bloemfontein       2
# Cape Town          7
# Centurion         12
# Chandigarh        42
# Chennai           48
# Cuttack            7
# Delhi             53
# Dharamsala         9
# Durban            15
# East London        3
# Hyderabad         41
# Indore             2
# Jaipur            33
# Johannesburg       8
# Kanpur             2
# Kimberley          3
# Kochi              5
# Kolkata           54
# Mumbai            77
# Nagpur             3
# Port Elizabeth     7
# Pune              25
# Raipur             6
# Rajkot             5
# Ranchi             7
# Sharjah            6
# Visakhapatnam     11
# dtype: int64

# %%
print(dt.isnull())
# Out:
#         id  season   city   date  team1  team2  toss_winner  toss_decision  \
# 0    False   False  False  False  False  False        False          False
# 1    False   False  False  False  False  False        False          False
# 2    False   False  False  False  False  False        False          False
# 3    False   False  False  False  False  False        False          False
# 4    False   False  False  False  False  False        False          False
# ..     ...     ...    ...    ...    ...    ...          ...            ...
# 572  False   False  False  False  False  False        False          False
# 573  False   False  False  False  False  False        False          False
# 574  False   False  False  False  False  False        False          False
# 575  False   False  False  False  False  False        False          False
# 576  False   False  False  False  False  False        False          False
#
# ...

# %%
print(dt.nunique())
# Out:
# id                 577
# season               9
# city                30
# date               407
# team1               13
# team2               13
# toss_winner         13
# toss_decision        2
# result               3
# dl_applied           2
# winner              13
# win_by_runs         83
# win_by_wickets      11
# player_of_match    187
# venue               35
# umpire1             43
# umpire2             45
# umpire3              0
# dtype: int64

# %%
print(dt)
# Out:
#       id  season        city        date                  team1  \
# 0      1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1      2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2      3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3      4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4      5    2008     Kolkata  2008-04-20        Deccan Chargers
# ..   ...     ...         ...         ...                    ...
# 572  573    2016      Raipur  2016-05-22       Delhi Daredevils
# 573  574    2016   Bangalore  2016-05-24          Gujarat Lions
# 574  575    2016       Delhi  2016-05-25    Sunrisers Hyderabad
# 575  576    2016       Delhi  2016-05-27          Gujarat Lions
# 576  577    2016   Bangalore  2016-05-29    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
print(dt.isnull().sum())
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               3
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              0
# umpire2              0
# umpire3            577
# dtype: int64

# %%
dt.nunique()
# Out:
# id                 577
# season               9
# city                30
# date               407
# team1               13
# team2               13
# toss_winner         13
# toss_decision        2
# result               3
# dl_applied           2
# winner              13
# win_by_runs         83
# win_by_wickets      11
# player_of_match    187
# venue               35
# umpire1             43
# umpire2             45
# umpire3              0
# dtype: int64

# %%
dt.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               3
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              0
# umpire2              0
# umpire3            577
# dtype: int64

# %%
dt.nunique()
# Out:
# id                 577
# season               9
# city                30
# date               407
# team1               13
# team2               13
# toss_winner         13
# toss_decision        2
# result               3
# dl_applied           2
# winner              13
# win_by_runs         83
# win_by_wickets      11
# player_of_match    187
# venue               35
# umpire1             43
# umpire2             45
# umpire3              0
# dtype: int64

# %%
sns.heatmap(dt.isnull())
# Out:
# <Axes: >

# %%
sns.barplot(x='season',y='winner',data=dt)
# Out:
# <Axes: xlabel='season', ylabel='winner'>

# %%
sns.pairplot(dt,hue='winner')

# %%
sns.jointplot(x='season',y='winner',data=dt)

# %%
dt['season'].max()
# Out:
# 2016

# %%
dt['season'].min()
# Out:
# 2008

# %%
dt.index
# Out:
# RangeIndex(start=0, stop=577, step=1)

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 577 entries, 0 to 576
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               577 non-null    int64
#  1   season           577 non-null    int64
#  2   city             570 non-null    object
#  3   date             577 non-null    object
#  4   team1            577 non-null    object
#  5   team2            577 non-null    object
#  6   toss_winner      577 non-null    object
#  7   toss_decision    577 non-null    object
#  8   result           577 non-null    object
#  9   dl_applied       577 non-null    int64
#  10  winner           574 non-null    object
#  11  win_by_runs      577 non-null    int64
#  12  win_by_wickets   577 non-null    int64
#  13  player_of_match  574 non-null    object
#  14  venue            577 non-null    object
#  15  umpire1          577 non-null    object
#  16  umpire2          577 non-null    object
# ...

# %%
dt.dtypes
# Out:
# id                   int64
# season               int64
# city                object
# date                object
# team1               object
# team2               object
# toss_winner         object
# toss_decision       object
# result              object
# dl_applied           int64
# winner              object
# win_by_runs          int64
# win_by_wickets       int64
# player_of_match     object
# venue               object
# umpire1             object
# umpire2             object
# umpire3            float64
# dtype: object

# %%
dt.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  577.000000   577.000000  577.000000   577.000000      577.000000
# mean   289.000000  2012.029463    0.025997    13.715771        3.363951
# std    166.709828     2.486247    0.159263    23.619282        3.416049
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    145.000000  2010.000000    0.000000     0.000000        0.000000
# 50%    289.000000  2012.000000    0.000000     0.000000        3.000000
# 75%    433.000000  2014.000000    0.000000    20.000000        6.000000
# max    577.000000  2016.000000    1.000000   144.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
dt.shape
# Out:
# (577, 18)

# %%
dt.dtypes.value_counts()
# Out:
# object     12
# int64       5
# float64     1
# Name: count, dtype: int64

# %%
dt['city'].describe()
# Out:
# count        570
# unique        30
# top       Mumbai
# freq          77
# Name: city, dtype: object

# %%
dt.sort_values(by='city')
# Out:
#       id  season       city        date                        team1  \
# 401  402    2014  Abu Dhabi  2014-04-18          Sunrisers Hyderabad
# 398  399    2014  Abu Dhabi  2014-04-16        Kolkata Knight Riders
# 400  401    2014  Abu Dhabi  2014-04-18          Chennai Super Kings
# 405  406    2014  Abu Dhabi  2014-04-21          Chennai Super Kings
# 411  412    2014  Abu Dhabi  2014-04-26  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 407  408    2014        NaN  2014-04-23          Chennai Super Kings
# 409  410    2014        NaN  2014-04-25          Sunrisers Hyderabad
# 410  411    2014        NaN  2014-04-25               Mumbai Indians
# 415  416    2014        NaN  2014-04-28  Royal Challengers Bangalore
# 417  418    2014        NaN  2014-04-30          Sunrisers Hyderabad
#
#                    team2            toss_winner toss_decision  result  \
# ...

# %%
dt.sort_values(by='city',ascending=False)
# Out:
#       id  season           city        date                        team1  \
# 471  472    2015  Visakhapatnam  2015-04-18             Delhi Daredevils
# 477  478    2015  Visakhapatnam  2015-04-22          Sunrisers Hyderabad
# 559  560    2016  Visakhapatnam  2016-05-13               Mumbai Indians
# 563  564    2016  Visakhapatnam  2016-05-15               Mumbai Indians
# 565  566    2016  Visakhapatnam  2016-05-17             Delhi Daredevils
# ..   ...     ...            ...         ...                          ...
# 407  408    2014            NaN  2014-04-23          Chennai Super Kings
# 409  410    2014            NaN  2014-04-25          Sunrisers Hyderabad
# 410  411    2014            NaN  2014-04-25               Mumbai Indians
# 415  416    2014            NaN  2014-04-28  Royal Challengers Bangalore
# 417  418    2014            NaN  2014-04-30          Sunrisers Hyderabad
#
#                        team2              toss_winner toss_decision  result  \
# ...

# %%
dt.sort_values(by=['city','season'])
# Out:
#       id  season       city        date                        team1  \
# 398  399    2014  Abu Dhabi  2014-04-16        Kolkata Knight Riders
# 400  401    2014  Abu Dhabi  2014-04-18          Chennai Super Kings
# 401  402    2014  Abu Dhabi  2014-04-18          Sunrisers Hyderabad
# 405  406    2014  Abu Dhabi  2014-04-21          Chennai Super Kings
# 411  412    2014  Abu Dhabi  2014-04-26  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 407  408    2014        NaN  2014-04-23          Chennai Super Kings
# 409  410    2014        NaN  2014-04-25          Sunrisers Hyderabad
# 410  411    2014        NaN  2014-04-25               Mumbai Indians
# 415  416    2014        NaN  2014-04-28  Royal Challengers Bangalore
# 417  418    2014        NaN  2014-04-30          Sunrisers Hyderabad
#
#                    team2            toss_winner toss_decision  result  \
# ...

# %%
dt.sort_values(by=['city','season'],ascending=[True,False])
# Out:
#       id  season       city        date                        team1  \
# 398  399    2014  Abu Dhabi  2014-04-16        Kolkata Knight Riders
# 400  401    2014  Abu Dhabi  2014-04-18          Chennai Super Kings
# 401  402    2014  Abu Dhabi  2014-04-18          Sunrisers Hyderabad
# 405  406    2014  Abu Dhabi  2014-04-21          Chennai Super Kings
# 411  412    2014  Abu Dhabi  2014-04-26  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 407  408    2014        NaN  2014-04-23          Chennai Super Kings
# 409  410    2014        NaN  2014-04-25          Sunrisers Hyderabad
# 410  411    2014        NaN  2014-04-25               Mumbai Indians
# 415  416    2014        NaN  2014-04-28  Royal Challengers Bangalore
# 417  418    2014        NaN  2014-04-30          Sunrisers Hyderabad
#
#                    team2            toss_winner toss_decision  result  \
# ...

# %%
dt.sort_index()
# Out:
#       id  season        city        date                  team1  \
# 0      1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1      2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2      3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3      4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4      5    2008     Kolkata  2008-04-20        Deccan Chargers
# ..   ...     ...         ...         ...                    ...
# 572  573    2016      Raipur  2016-05-22       Delhi Daredevils
# 573  574    2016   Bangalore  2016-05-24          Gujarat Lions
# 574  575    2016       Delhi  2016-05-25    Sunrisers Hyderabad
# 575  576    2016       Delhi  2016-05-27          Gujarat Lions
# 576  577    2016   Bangalore  2016-05-29    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
days=dt[['city','season']]
days
# Out:
#            city  season
# 0     Bangalore    2008
# 1    Chandigarh    2008
# 2         Delhi    2008
# 3        Mumbai    2008
# 4       Kolkata    2008
# ..          ...     ...
# 572      Raipur    2016
# 573   Bangalore    2016
# 574       Delhi    2016
# 575       Delhi    2016
# 576   Bangalore    2016
#
# [577 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# days['season'].plot(kind='hist', bins=20, title='season')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['season']
# ...

# %%
dt.columns.values
# Out:
# array(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'], dtype=object)

# %%
dt[10:]
# Out:
#       id  season        city        date                        team1  \
# 10    11    2008   Bangalore  2008-04-26  Royal Challengers Bangalore
# 11    12    2008     Chennai  2008-04-26        Kolkata Knight Riders
# 12    13    2008      Mumbai  2008-04-27               Mumbai Indians
# 13    14    2008  Chandigarh  2008-04-27             Delhi Daredevils
# 14    15    2008   Bangalore  2008-04-28          Chennai Super Kings
# ..   ...     ...         ...         ...                          ...
# 572  573    2016      Raipur  2016-05-22             Delhi Daredevils
# 573  574    2016   Bangalore  2016-05-24                Gujarat Lions
# 574  575    2016       Delhi  2016-05-25          Sunrisers Hyderabad
# 575  576    2016       Delhi  2016-05-27                Gujarat Lions
# 576  577    2016   Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
dt[10:20]
# Out:
#     id  season        city        date                        team1  \
# 10  11    2008   Bangalore  2008-04-26  Royal Challengers Bangalore
# 11  12    2008     Chennai  2008-04-26        Kolkata Knight Riders
# 12  13    2008      Mumbai  2008-04-27               Mumbai Indians
# 13  14    2008  Chandigarh  2008-04-27             Delhi Daredevils
# 14  15    2008   Bangalore  2008-04-28          Chennai Super Kings
# 15  16    2008     Kolkata  2008-04-29        Kolkata Knight Riders
# 16  17    2008       Delhi  2008-04-30             Delhi Daredevils
# 17  18    2008   Hyderabad  2008-05-01              Deccan Chargers
# 18  19    2008      Jaipur  2008-05-01             Rajasthan Royals
# 19  20    2008     Chennai  2008-05-02          Chennai Super Kings
#
#                           team2                  toss_winner toss_decision  \
# 10             Rajasthan Royals             Rajasthan Royals         field
# ...

# %%
dt[:10]
# Out:
#    id  season        city        date                  team1  \
# 0   1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1   2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2   3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3   4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4   5    2008     Kolkata  2008-04-20        Deccan Chargers
# 5   6    2008      Jaipur  2008-04-21        Kings XI Punjab
# 6   7    2008   Hyderabad  2008-04-22        Deccan Chargers
# 7   8    2008     Chennai  2008-04-23    Chennai Super Kings
# 8   9    2008   Hyderabad  2008-04-24        Deccan Chargers
# 9  10    2008  Chandigarh  2008-04-25        Kings XI Punjab
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# ...

# %%
sns.scatterplot(x='city',y='season',data=dt)
# Out:
# <Axes: xlabel='city', ylabel='season'>

# %%
sns.scatterplot(x='city',y='season',data=dt,hue='winner')
# Out:
# <Axes: xlabel='city', ylabel='season'>

# %%
sns.histplot(x='city',data=dt)
# Out:
# <Axes: xlabel='city', ylabel='Count'>

# %%
city=dt['winner'].value_counts()
city
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sns.boxplot(x='city',y='season',data=dt)
# Out:
# <Axes: xlabel='city', ylabel='season'>

# %%
sns.boxplot(dt['city'])
# Out:
# <Axes: ylabel='city'>

# %%
dt['deck_bca']=np.where(dt['city']=='Hyderabad','ic','kc')
dt
# Out:
#       id  season        city        date                  team1  \
# 0      1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1      2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2      3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3      4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4      5    2008     Kolkata  2008-04-20        Deccan Chargers
# ..   ...     ...         ...         ...                    ...
# 572  573    2016      Raipur  2016-05-22       Delhi Daredevils
# 573  574    2016   Bangalore  2016-05-24          Gujarat Lions
# 574  575    2016       Delhi  2016-05-25    Sunrisers Hyderabad
# 575  576    2016       Delhi  2016-05-27          Gujarat Lions
# 576  577    2016   Bangalore  2016-05-29    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
dt['deck_bca'].value_counts()
# Out:
# deck_bca
# kc    536
# ic     41
# Name: count, dtype: int64

# %%
dt['city'].fillna('Hyderabad',inplace=True)
dt
# Out:
#       id  season        city        date                  team1  \
# 0      1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1      2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2      3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3      4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4      5    2008     Kolkata  2008-04-20        Deccan Chargers
# ..   ...     ...         ...         ...                    ...
# 572  573    2016      Raipur  2016-05-22       Delhi Daredevils
# 573  574    2016   Bangalore  2016-05-24          Gujarat Lions
# 574  575    2016       Delhi  2016-05-25    Sunrisers Hyderabad
# 575  576    2016       Delhi  2016-05-27          Gujarat Lions
# 576  577    2016   Bangalore  2016-05-29    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
corr = dt[['season', 'id', 'win_by_runs']].corr()
print(corr)
sns.heatmap(corr, annot=True)
# Out:
#                season        id  win_by_runs
# season       1.000000  0.992806    -0.018098
# id           0.992806  1.000000    -0.014813
# win_by_runs -0.018098 -0.014813     1.000000
# <Axes: >
